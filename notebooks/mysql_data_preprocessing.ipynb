# %%
import os

import pandas as pd
import numpy as np
from dotenv import load_dotenv
from sqlalchemy import types, create_engine
from matplotlib.pyplot import plot as plt

# %matplotlib inline
load_dotenv()
# Out:
# True

# %%
MYSQL_USERNAME = os.getenv("MYSQL_USERNAME")
MYSQL_PASSWORD = os.getenv("MYSQL_PASSWORD")
MYSQL_HOST = os.getenv("SERVER_IP")
MYSQL_PORT = os.getenv("MYSQL_PORT")
MYSQL_DATABASE = os.getenv("MYSQL_DATABASE")
MYSQL_URI = "mysql+pymysql://{}:{}@{}:{}/{}".format(MYSQL_USERNAME, MYSQL_PASSWORD, MYSQL_HOST, MYSQL_PORT, MYSQL_DATABASE)
print(MYSQL_URI)
engine = create_engine(MYSQL_URI, echo=False)
# Out:
# mysql+pymysql://admin:Alpacas1@167.99.255.7:3306/covid19

# %%
columns_to_use = [
    'iso_code',
    'continent',
    'location',
    'date',
    'new_cases',
    'new_deaths',
    'new_tests',
    'population',
    'population_density',
    'median_age',
    'aged_65_older',
    'gdp_per_capita',
    'extreme_poverty',
    'cardiovasc_death_rate',
    'diabetes_prevalence',
    'female_smokers',
    'male_smokers',
    'life_expectancy',
    'human_development_index'
]

# %%
df = pd.read_csv("../data/owid-covid-2020-11-18.csv", usecols=columns_to_use)

# %%
df.head(5)
# Out:
#   iso_code continent     location        date  new_cases  new_deaths  \
# 0      AFG      Asia  Afghanistan  2019-12-31        0.0         0.0
# 1      AFG      Asia  Afghanistan  2020-01-01        0.0         0.0
# 2      AFG      Asia  Afghanistan  2020-01-02        0.0         0.0
# 3      AFG      Asia  Afghanistan  2020-01-03        0.0         0.0
# 4      AFG      Asia  Afghanistan  2020-01-04        0.0         0.0
#
#    new_tests  population  population_density  median_age  aged_65_older  \
# 0        NaN  38928341.0              54.422        18.6          2.581
# 1        NaN  38928341.0              54.422        18.6          2.581
# 2        NaN  38928341.0              54.422        18.6          2.581
# 3        NaN  38928341.0              54.422        18.6          2.581
# 4        NaN  38928341.0              54.422        18.6          2.581
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
len(df.date.unique())
# Out:
# 324

# %%
df = df[(df["iso_code"] != "OWID_WRL") & (df["iso_code"].notna())]

# %%
df["date"] = df["date"].apply(pd.to_datetime)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56965 entries, 0 to 56964
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   iso_code                 56965 non-null  object
#  1   continent                56965 non-null  object
#  2   location                 56965 non-null  object
#  3   date                     56965 non-null  datetime64[ns]
#  4   new_cases                56295 non-null  float64
#  5   new_deaths               56295 non-null  float64
#  6   new_tests                21787 non-null  float64
#  7   population               56965 non-null  float64
#  8   population_density       54253 non-null  float64
#  9   median_age               50902 non-null  float64
#  10  aged_65_older            50130 non-null  float64
#  11  gdp_per_capita           50233 non-null  float64
#  12  extreme_poverty          33375 non-null  float64
# ...

# %%
table_name = 'country'

df.to_sql(
    table_name,
    engine,
    if_exists='replace',
    index=False,
    chunksize=500,
    dtype={
        "iso_code": types.String(20),
        "continent": types.String(255),
        "location": types.String(255),
        "date":  types.Date,
        "new_cases": types.Float,
        "new_deaths": types.Float,
        "new_tests": types.Float,
        "population": types.Float,
        "population_density": types.Float,
        "median_age": types.Float,
        "aged_65_older": types.Float,
        "gdp_per_capita": types.Float,
        "extreme_poverty": types.Float,
        "cardiovasc_death_rate": types.Float,
        "diabetes_prevalence": types.Float,
        "female_smokers": types.Float,
        "male_smokers": types.Float,
        "life_expectancy": types.Float,
        "human_development_index": types.Float
    }
)
# Out:
# 2020-11-19 20:16:30,075 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'sql_mode'
# 2020-11-19 20:16:30,076 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-19 20:16:30,107 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'lower_case_table_names'
# 2020-11-19 20:16:30,107 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-19 20:16:30,166 INFO sqlalchemy.engine.base.Engine SELECT DATABASE()
# 2020-11-19 20:16:30,166 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-19 20:16:30,221 INFO sqlalchemy.engine.base.Engine show collation where `Charset` = 'utf8mb4' and `Collation` = 'utf8mb4_bin'
# 2020-11-19 20:16:30,222 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-19 20:16:30,251 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS CHAR(60)) AS anon_1
# 2020-11-19 20:16:30,252 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-19 20:16:30,280 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS CHAR(60)) AS anon_1
# ...
